# %% [markdown]
# # Table of Contents
# 1. Importing Data
# 2. Columns to delete
# 3. Merge the two DataFrames on a common column (e.g., 'product_id')
# 4. Export DF

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
path = r'C:\Users\olivi\OneDrive\Documents\Data Analytics\Data Analytics Immersion\Instacart Basket Analysis'

# %%
df_ords_prior = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_combined.pkl'))

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_checked.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path , '02 Data' , 'Prepared Data' , 'products_checked.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_order  product_id  add_to_cart_order  reordered _merge
# 0          11.11484         196                  1          0   both
# 1          11.11484       14084                  2          0   both
# 2          11.11484       12427                  3          0   both
# 3          11.11484       26088                  4          0   both
# 4          11.11484       26405                  5          0   both

# %%
# 2. Columns to delete
columns_to_delete = ['Unnamed: 0.1', 'Unnamed: 0']

# Drop the columns
df_ords = df_ords.drop(columns=columns_to_delete)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 columns_to_delete = ['Unnamed: 0.1', 'Unnamed: 0']
#       4 # Drop the columns
# ----> 5 df_ords = df_ords.drop(columns=columns_to_delete)
#
# NameError: name 'df_ords' is not defined

# %%
df_ords_prior.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_order  product_id  add_to_cart_order  reordered _merge
# 0          11.11484         196                  1          0   both
# 1          11.11484       14084                  2          0   both
# 2          11.11484       12427                  3          0   both
# 3          11.11484       26088                  4          0   both
# 4          11.11484       26405                  5          0   both

# %%
# Columns to delete
columns_to_delete = ['Unnamed: 0.1']

# Drop the columns
df_prods = df_prods.drop(columns=columns_to_delete)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prior.shape
# Out:
# (32434489, 10)

# %%
df_prods.shape
# Out:
# (49677, 6)

# %% [markdown]
# # 3. Merge the two DataFrames on a common column (e.g., 'product_id')

# %%
df_merged_large = pd.merge(df_prods, df_ords_prior, on='product_id', how='inner')

# Display the merged DataFrame
print(df_merged_large)
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32406036       49692       49688      Fresh Foaming Cleanser        73
# 32406037       49692       49688      Fresh Foaming Cleanser        73
# 32406038       49692       49688      Fresh Foaming Cleanser        73
# 32406039       49692       49688      Fresh Foaming Cleanser        73
# 32406040       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  user_id  order_number  \
# ...

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  orders_day_of_week  \
# 0             19     5.8   3139998      138            28                   6
# 1             19     5.8   1977647      138            30                   6
# 2             19     5.8    389851      709             2                   0
# 3             19     5.8    652770      764             1                   3
# 4             19     5.8   1813452      764             3                   4
#
#    order_hour_of_day  days_since_order  add_to_cart_order  reordered _merge
# ...

# %% [markdown]
# # Export Df

# %%
# Save the DataFrame to a pickle file
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
